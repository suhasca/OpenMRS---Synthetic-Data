# %%
pip install faker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
import pandas as pd
import random

# Initialising Faker
fake_ar = Faker('ar_SA')
fake_en = Faker()

# Extended lists of common Muslim first and last names with their English equivalents and gender

more_muslim_first_names_with_gender = {
    'طارق': {'name': 'Tariq', 'gender': 'Male'}, 
    'رشيد': {'name': 'Rashid', 'gender': 'Male'}, 
    'عبد الله': {'name': 'Abdullah', 'gender': 'Male'}, 
    'عبد الغني': {'name': 'Abdul Ghani', 'gender': 'Male'}, 
    'عبد القدوس': {'name': 'Abdul Quddus', 'gender': 'Male'}, 
    'عبد الودود': {'name': 'Abdul Wadood', 'gender': 'Male'}, 
    'عبد المتين': {'name': 'Abdul Mateen', 'gender': 'Male'}, 
    'عبد الحافظ': {'name': 'Abdul Hafiz', 'gender': 'Male'}, 
    'عبد العظيم': {'name': 'Abdul Azeem', 'gender': 'Male'}, 
    'عبد المجيد': {'name': 'Abdul Majeed', 'gender': 'Male'}, 
    'سليمان': {'name': 'Suleiman', 'gender': 'Male'}, 
    'حكيم': {'name': 'Hakeem', 'gender': 'Male'}, 
    'هيثم': {'name': 'Haitham', 'gender': 'Male'}, 
    'عادل': {'name': 'Adil', 'gender': 'Male'}, 
    'بدر': {'name': 'Badr', 'gender': 'Male'}, 
    'ريحانة': {'name': 'Rihana', 'gender': 'Female'}, 
    'جميلة': {'name': 'Jamila', 'gender': 'Female'}, 
    'عائشة': {'name': 'Aisha', 'gender': 'Female'}, 
    'حنان': {'name': 'Hanan', 'gender': 'Female'}, 
    'نور': {'name': 'Noor', 'gender': 'Female'}, 
    'عزة': {'name': 'Azza', 'gender': 'Female'}, 
    'فرح': {'name': 'Farah', 'gender': 'Female'}, 
    'ابتسام': {'name': 'Ibtisam', 'gender': 'Female'}, 
    'سارة': {'name': 'Sarah', 'gender': 'Female'}, 
    'أماني': {'name': 'Amani', 'gender': 'Female'}, 
    'بشرى': {'name': 'Bushra', 'gender': 'Female'}, 
    'راوية': {'name': 'Rawiya', 'gender': 'Female'}, 
    'نجلاء': {'name': 'Naglaa', 'gender': 'Female'}, 
    'ضحى': {'name': 'Doha', 'gender': 'Female'}, 
    'مها': {'name': 'Maha', 'gender': 'Female'},
    'زكريا': {'name': 'Zakaria', 'gender': 'Male'}, 
    'مالك': {'name': 'Malik', 'gender': 'Male'}, 
    'شادي': {'name': 'Shadi', 'gender': 'Male'}, 
    'سامي': {'name': 'Sami', 'gender': 'Male'}, 
    'سهيل': {'name': 'Suhail', 'gender': 'Male'}, 
    'ثابت': {'name': 'Thabit', 'gender': 'Male'}, 
    'جميل': {'name': 'Jameel', 'gender': 'Male'}, 
    'مراد': {'name': 'Murad', 'gender': 'Male'}, 
    'قاسم': {'name': 'Qasim', 'gender': 'Male'}, 
    'أكرم': {'name': 'Akram', 'gender': 'Male'}, 
    'مروان': {'name': 'Marwan', 'gender': 'Male'}, 
    'أسامة': {'name': 'Osama', 'gender': 'Male'}, 
    'معاذ': {'name': 'Muadh', 'gender': 'Male'}, 
    'أديب': {'name': 'Adeeb', 'gender': 'Male'}, 
    'لبنى': {'name': 'Lubna', 'gender': 'Female'}, 
    'سناء': {'name': 'Sana', 'gender': 'Female'}, 
    'عليا': {'name': 'Aliya', 'gender': 'Female'}, 
    'سلوى': {'name': 'Salwa', 'gender': 'Female'}, 
    'غادة': {'name': 'Ghada', 'gender': 'Female'}, 
    'ميساء': {'name': 'Maysa', 'gender': 'Female'}, 
    'نجوى': {'name': 'Najwa', 'gender': 'Female'}, 
    'ريم': {'name': 'Reem', 'gender': 'Female'}, 
    'ليلى': {'name': 'Layla', 'gender': 'Female'}, 
    'هناء': {'name': 'Hanaa', 'gender': 'Female'}, 
    'نهى': {'name': 'Noha', 'gender': 'Female'}, 
    'رانية': {'name': 'Rania', 'gender': 'Female'}, 
    'نوال': {'name': 'Nawal', 'gender': 'Female'}, 
    'خلود': {'name': 'Kholoud', 'gender': 'Female'}, 
    'لمياء': {'name': 'Lamia', 'gender': 'Female'},
        'أمين': {'name': 'Ameen', 'gender': 'Male'},
    'رياض': {'name': 'Riyad', 'gender': 'Male'},
    'وحيد': {'name': 'Waheed', 'gender': 'Male'},
    'فارس': {'name': 'Faris', 'gender': 'Male'},
    'أدهم': {'name': 'Adham', 'gender': 'Male'},
    'منصور': {'name': 'Mansoor', 'gender': 'Male'},
    'إيهاب': {'name': 'Ehab', 'gender': 'Male'},
    'سيف': {'name': 'Saif', 'gender': 'Male'},
    'رامي': {'name': 'Rami', 'gender': 'Male'},
    'فيصل': {'name': 'Faisal', 'gender': 'Male'},
    'سليم': {'name': 'Saleem', 'gender': 'Male'},
    'هاشم': {'name': 'Hashim', 'gender': 'Male'},
    'فايز': {'name': 'Faiz', 'gender': 'Male'},
    'هشام': {'name': 'Hisham', 'gender': 'Male'},
    'جواد': {'name': 'Jawad', 'gender': 'Male'},
    'زينب': {'name': 'Zainab', 'gender': 'Female'},
    'مريم': {'name': 'Maryam', 'gender': 'Female'},
    'لبنى': {'name': 'Lubna', 'gender': 'Female'},
    'سمر': {'name': 'Samar', 'gender': 'Female'},
    'عبير': {'name': 'Abeer', 'gender': 'Female'},
    'إلهام': {'name': 'Elham', 'gender': 'Female'},
    'هدى': {'name': 'Huda', 'gender': 'Female'},
    'وردة': {'name': 'Warda', 'gender': 'Female'},
    'هند': {'name': 'Hind', 'gender': 'Female'},
    'ياسمين': {'name': 'Yasmin', 'gender': 'Female'},
    'جنان': {'name': 'Janan', 'gender': 'Female'},
    'نسرين': {'name': 'Nisreen', 'gender': 'Female'},
    'منى': {'name': 'Muna', 'gender': 'Female'},
    'إيمان': {'name': 'Iman', 'gender': 'Female'},
    'بتول': {'name': 'Batool', 'gender': 'Female'}
}


muslim_family_names = {
    'القريشي': 'Qureshi', 'الأنصاري': 'Ansari', 'الشريف': 'Sharif', 'الحسني': 'Hassani', 
    'التميمي': 'Tamimi', 'الهاشمي': 'Hashimi', 'السيد': 'Sayyid', 'الفاروقي': 'Farooqi',
    'الصديقي': 'Siddiqui', 'العثماني': 'Othmani', 'العباسي': 'Abbasi', 'البغدادي': 'Baghdadi',
    'الحارثي': 'Harithi', 'الدوسري': 'Dossary', 'الراشدي': 'Rashidi', 'الزهراني': 'Zahrani',
    'العقبي': 'Aqbi', 'البدري': 'Badri', 'الخطيب': 'Khatib', 'المصري': 'Masri', 'الجزائري': 'Jazaeri', 
     'الشيباني': 'Shaibani', 'الغزاوي': 'Ghazzawi', 'البصري': 'Basri', 'الأشقر': 'Ashqar', 
    'الدعجاني': 'Dajjani', 'الشامي': 'Shami', 'الرفاعي': 'Rifai', 'السباعي': 'Sabai',
    'السعودي': 'Saoudi', 'الهاشمي': 'Hashimi', 'العبدلي': 'Abdali', 'المعري': 'Maarri',
    'الخزعلي': 'Khazali', 'العقيل': 'Aqil', 'القحطاني': 'Qahtani', 'الدوسري': 'Dossary',
    'المقرن': 'Mogren', 'المطيري': 'Motairy', 'البليهي': 'Blahe', 'الرشيدي': 'Rashidi',
    'الفلاسي': 'Falasi', 'العتيبي': 'Otaibi', 'الزهراني': 'Zahrani', 'الغامدي': 'Ghamdi',
    'الشبرمي': 'Shabrami', 'الحجيري': 'Hujairi', 'الحارثي': 'Harithi', 'الحسيني': 'Hussaini',
    'المعمر': 'Muammar', 'الشحي': 'Shahi', 'النقشبندي': 'Naqshbandi','الطرابلسي': 'Trabelsi',
    'الكتاني': 'Kettani','الفاسي': 'Fassi','العمراني': 'Omrani','البارقي': 'Barqi',
    'الطائي': 'Tai','الماجد': 'Majid','المزروعي': 'Mazroui','الغامدي': 'Ghamdi',
    'المغربي': 'Maghribi','اليمني': 'Yemeni','النجدي': 'Najdi','المكي': 'Maki','اللبناني': 'Lebnani',
    'الشاطري': 'Shatiri','الرفاعي': 'Rifai','القاسمي': 'Qasimi','النبهاني': 'Nabhani',
    'الجريري': 'Jariri','المدني': 'Madani','البصري': 'Basri', 'الطبراني': 'Tabarani',
    'الصقلي': 'Siqilli','المراكشي': 'Marakshi','التلمساني': 'Tilimsani','النجار': 'Najjar','المقدسي': 'Maqdisi',
    'المزني': 'Mazni'
}

# Generate a list of fake names
num_names = 1000  # Adjust the number of names as needed
data = []

for i in range(1, num_names + 1):
    first_name_ar = random.choice(list(more_muslim_first_names_with_gender.keys()))
    family_name_ar = random.choice(list(muslim_family_names.keys()))
    first_name_en = more_muslim_first_names_with_gender[first_name_ar]['name']
    gender = more_muslim_first_names_with_gender[first_name_ar]['gender']
    family_name_en = muslim_family_names[family_name_ar]
    combined_first_name = f"{first_name_ar} ({first_name_en})"
    combined_family_name = f"{family_name_ar} ({family_name_en})"
    data.append([i, combined_first_name, combined_family_name, gender])

# Convert to a DataFrame
df = pd.DataFrame(data, columns=["ID", "First Name", "Family Name", "Gender"])

# Save to CSV with UTF-8 encoding
df.to_csv("fake_arabic_names_with_gender.csv", index=False, encoding='utf-8-sig')

# Display the head of the DataFrame
print(df.head())

print("Fake Arabic names with gender saved to fake_arabic_names_with_gender.csv with UTF-8 encoding")
# Out:
#    ID               First Name          Family Name  Gender
# 0   1            فيصل (Faisal)   النبهاني (Nabhani)    Male
# 1   2               نهى (Noha)   النبهاني (Nabhani)  Female
# 2   3               منى (Muna)     الغامدي (Ghamdi)  Female
# 3   4  عبد الغني (Abdul Ghani)   المزروعي (Mazroui)    Male
# 4   5             نجوى (Najwa)  الطبراني (Tabarani)  Female
# Fake Arabic names with gender saved to fake_arabic_names_with_gender.csv with UTF-8 encoding

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each gender
gender_counts = df['Gender'].value_counts()

# Create a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(gender_counts.index, gender_counts.values, color=['blue', 'pink'])

# Add text annotations
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, int(yval), ha='center', va='bottom')

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution in Fake Arabic Names')
plt.xticks(rotation=0)
plt.show()
